# %%
# excel file uploading for ML
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/collab  notebook/wine.csv")
df
# Out:
#     Alchohol  Acididity  outcomes
# 0        9.3        3.4         1
# 1        9.1        4.4         1
# 2        9.2        2.3         1
# 3        9.5        4.4         1
# 4        9.8        5.2         1
# 5        9.6        5.0         1
# 6        3.5        2.3         0
# 7        3.8        2.0         0
# 8        8.0        3.3         0
# 9        7.0        2.0         0
# 10       7.6        5.5         0
# 11       7.0        6.0         0
# 12       9.0        9.0         0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# GIVE INPUT AND OUTPUT FOR PC
x=df.iloc[:,[0,1]]
y=df.iloc[:,[2]]

# %%
x
# Out:
#     Alchohol  Acididity
# 0        9.3        3.4
# 1        9.1        4.4
# 2        9.2        2.3
# 3        9.5        4.4
# 4        9.8        5.2
# 5        9.6        5.0
# 6        3.5        2.3
# 7        3.8        2.0
# 8        8.0        3.3
# 9        7.0        2.0
# 10       7.6        5.5
# 11       7.0        6.0
# 12       9.0        9.0

# %%
y
# Out:
#     outcomes
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1
# 6          0
# 7          0
# 8          0
# 9          0
# 10         0
# 11         0
# 12         0

# %%
from sklearn.model_selection import train_test_split
x_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#     Alchohol  Acididity
# 2        9.2        2.3
# 8        8.0        3.3
# 1        9.1        4.4
# 7        3.8        2.0
# 9        7.0        2.0
# 3        9.5        4.4
# 0        9.3        3.4
# 5        9.6        5.0
# 12       9.0        9.0

# %%
X_test
# Out:
#     Alchohol  Acididity
# 6        3.5        2.3
# 11       7.0        6.0
# 4        9.8        5.2
# 10       7.6        5.5

# %%
y_train
# Out:
#     outcomes
# 2          1
# 8          0
# 1          1
# 7          0
# 9          0
# 3          1
# 0          1
# 5          1
# 12         0

# %%
y_test
# Out:
#     outcomes
# 6          0
# 11         0
# 4          1
# 10         0

# %% [markdown]
# **random forest**

# %%
#random forest
from sklearn.ensemble import RandomForestRegressor
clf=RandomForestRegressor(n_estimators=100)
clf.fit(x_train,y_train)
y_pred=clf.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
y_pred
# Out:
# array([0.06, 0.13, 1.  , 0.13])

# %%
from sklearn.metrics import accuracy_score
y_test=y_test.astype(int)
y_pred=y_pred.astype(int)
a=accuracy_score(y_test,y_pred)*100
a
# Out:
# 100.0

# %%
a=float(input("enter amount of alcohol:"))
b=float(input("enter the acid level:"))
data=[[a,b]]
df1=pd.DataFrame(data,columns=['Alchohol','Acididity'])
#perform predition
o=clf.predict(df1)
if o>0.5:
  print("it is wine")
else:
    print("it is not wine")
# Out:
# enter amount of alcohol:6
# enter the acid level:4
# it is not wine
